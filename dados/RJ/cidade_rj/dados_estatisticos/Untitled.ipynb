# %%
import pickle

# %%
with open('landScan.bin', 'rb') as file:
    dados = pickle.load(file)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dados = array(dados)

# %%
dados[dados == 0] = -30000

# %%
figure(figsize=(16, 10))
imshow(dados)
colorbar()

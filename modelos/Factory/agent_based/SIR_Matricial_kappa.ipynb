# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import lognorm
import sys
import os

# %%
mean = 0.72
sigma = 1.8
mu = np.exp(mean)

# %%
def ln(x, s):
    return 1/(s * x * np.sqrt(np.pi * 2)) * np.exp(-np.log(np.log(x))/(2 * s**2))

# %%
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../../..')))
import episiming

# %%
num_pop = 10
populacao = np.ones_like(range(10))
populacao[0] = 2
pop_0 = populacao
T_prob_nao_infeccao = 0
prob_nao_recuperacao = 1
duracao_infeccao = 10
tempo_infeccao = []
for i, p in enumerate(populacao):
    if p == 2:
        tempo_infeccao.append([0, i])
tempo_infeccao_0 = tempo_infeccao

# %%
l = np.array([False,True,False,True])
a = np.arange(len(l))
ti = a[l]
td = np.zeros_like(ti)
np.vstack([td, ti]).reshape(2,2).T
a[l]
# Out:
# array([1, 3])

# %%
t_0 = 0
dt = 1
num_dt = 60
T = t_0 + num_dt*dt
dados_temporais = [t_0, dt, num_dt]
tempos = np.linspace(t_0, num_dt*dt, num_dt+1)
num_sim = 20

# %%
rede_completa = episiming.cenarios.RedeCompleta(300, 20, 0.5, 0.1, duracao_infeccao=5)

# %%
[1,2,3,4].remove(2)

# %%
np.delete(np.array([1,2,3,4]), 2)
# Out:
# array([1, 2, 4])

# %%
a = np.array([[1, 2]])
b = np.array([[5, 6]])
np.concatenate((a, b), axis=0)
# Out:
# array([[1, 2],
#        [5, 6]])

# %%
np.concatenate(([[0,0]], [[4, 5]]))
# Out:
# array([[0, 0],
#        [4, 5]])

# %%
X_comp = rede_completa.evolui_matricial(dados_temporais, num_sim, show='sd', kappa=True)

# %%
np.array([[1,2], [3,4]])/np.array([[1,2], [3,4]])
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
X_comp.I_medio
# Out:
# array([ 20.  ,  29.6 ,  43.25,  61.55,  86.25, 115.25, 136.3 , 154.2 ,
#        164.  , 161.05, 147.75, 129.35, 106.75,  84.95,  66.65,  52.65,
#         42.4 ,  35.2 ,  30.45,  27.95,  26.05,  24.9 ,  23.85,  23.25,
#         22.95,  22.7 ,  22.2 ,  22.4 ,  22.1 ,  21.85,  21.7 ,  21.85,
#         21.5 ,  21.4 ,  21.15,  21.1 ,  21.25,  20.95,  20.9 ,  21.15,
#         21.1 ,  20.75,  20.75,  20.8 ,  20.85,  20.8 ,  20.85,  20.95,
#         20.85,  20.5 ,  20.5 ,  20.35,  20.3 ,  20.2 ,  20.3 ,  20.4 ,
#         20.5 ,  20.35,  20.65,  20.7 ,  20.6 ])

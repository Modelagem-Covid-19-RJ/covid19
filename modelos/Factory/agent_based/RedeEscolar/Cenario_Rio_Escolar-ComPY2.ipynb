# %% [markdown]
# <!--HEADER-->
# [*Notas sobre modelagem da epidemia de Covid-19*](https://github.com/rmsrosa/modcovid19) / [*IM-UFRJ*](https://www.im.ufrj.br).

# %% [markdown]
# # O cenário da cidade do Rio de Janeiro: rede escolar
#
# - Continuando a criação de cenários que sejam **múltiplos** do cenário `Pop350` visto anteriormente.
#
# - Neste segundo caderno da série, ...

# %%
import datetime # date and time tools

import os, sys

import math

import random

import numpy as np
from scipy import stats

import networkx as nx

import matplotlib.pyplot as plt
import seaborn as sns

import io, base64
from IPython.display import Image, HTML

import pandas as pd

import rede_escolar

# %%
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../../../..')))
import episiming

# %%
sns.set_style("darkgrid")

# %%
dt_string = datetime.datetime.now().strftime("%d/%b/%Y")
print(f"Atualização mais recente do kernel: {dt_string}")
# Out:
# Atualização mais recente do kernel: 12/Jul/2020

# %% [markdown]
# ## Distribuição populacional da cidade do Rio de Janeiro
#
# Primeiramente, conforme feito anteriormente:
#
# - posicionamos as residências;
#
# - distribuímos os indivíduos em suas residências; e
#
# - posicionamos os indivíduos em torno de suas residências.

# %% [markdown]
# ### Carregando os dados
#
# Carregamos os dados populacionais por quilômetro quadrado da cidade do Rio de Janeiro obtidos do [Landscan](https://landscan.ornl.gov), mudando para 0 o valor das células com -1.

# %%
landscan_rio = np.load('../../../../dados/RJ/cidade_rj/dados_estatisticos/LandScan.npy').astype(int)
landscan_rio = np.maximum(landscan_rio, 0)

# %% [markdown]
# Carregamos os dados de escolas por quilômetro quadrado da cidade do Rio de Janeiro, obtidos do [IPP/Data Rio](https://www.data.rio/datasets/escolas-municipais)

# %%
escolas_municipais = np.load('../../../../dados/RJ/cidade_rj/dados_estatisticos/Municipais.npy').astype(int)

# %% [markdown]
# ### Visualização em escala logarítmica
#
# Visualizamos
#
# $$ ln( 1 + \textrm{população})
# $$

# %%
plt.figure(figsize=(16,6))
plt.imshow(np.log(1 + landscan_rio), cmap='Blues', interpolation='none')
plt.grid(False)
plt.title(f'Distribuição da população de {int(landscan_rio.sum())} indivíduos', fontsize=16)
plt.show()

# %% [markdown]
# ## Rede residencial
#
# Montamos a rede residencial como antes.
#
# O importante para a montagem da rede de empresas não é a rede residencial em si, apenas a localização dos indivíduos feita na construção da rede residencial.

# %% [markdown]
# ### Reduzindo a população
#
# Com o objetivo de realizar testes mais rápidos, com populações menores, dividimos a população de cada bloco por um determinado fator.
#
# Essa divisão nos dá números em ponto flutuante, que então truncamos para a sua parte inteira.

# %%
censo_residencial = np.array([.21, .26, .20, .17, .08, .04, .02, 0.02])
pop_por_blocos = (landscan_rio/100).astype(int)

# %%
plt.figure(figsize=(16,6))
plt.imshow(np.log(1 + pop_por_blocos), cmap='coolwarm', interpolation='none')
#plt.colorbar()
plt.grid(False)
plt.title(f'Distribuição da população de {pop_por_blocos.sum()} indivíduos', fontsize=16)
plt.show()

# %% [markdown]
# ### Distribuindo e alocando os indivíduos e as suas residências

# %%
# %%time
pos_residencias, pos_individuos, res_individuos, pop_blocos_indices \
    = episiming.cenarios.aloca_residencias_e_individuos(pop_por_blocos, censo_residencial)
# Out:
# CPU times: user 511 ms, sys: 0 ns, total: 511 ms
# Wall time: 510 ms

# %%
pop_blocos_indices[-1]
# Out:
# 67973

# %% [markdown]
# ### Gerando o grafo da rede residencial

# %%
# %%time
attrib_pos_individuos = {j: pos_individuos[j] for j in range(len(pos_individuos))}

G_r = nx.random_geometric_graph(len(pop_por_blocos), 0, pos=attrib_pos_individuos)

for individuos in res_individuos:
    if len(individuos) > 1:
        G_r.add_edges_from([(i,j) for i in individuos for j in individuos if i < j])
# Out:
# CPU times: user 248 ms, sys: 13.5 ms, total: 261 ms
# Wall time: 261 ms

# %% [markdown]
# ### Viualização

# %%
# %%time
plt.figure(figsize=(12,6))
nx.draw(G_r, pos=attrib_pos_individuos, node_size=1, alpha=0.5)
plt.show()
# Out:
# CPU times: user 827 ms, sys: 161 ms, total: 988 ms
# Wall time: 688 ms

# %% [markdown]
# ## Rede escolar
#
# Na construção da rede escolar, a ideia é fazer os seguintes passos:
#
# - Temos as distribuições geolocalizadas das escolas.
#
# - A partir do censo de idade populacional, determinar a parte da população a ser alocada nas escolas
#
# - Para alocar a população nas escolas: Calculamos a distância de cada individuo para todas as escolas, e tomamos as 3 escolas mais próximas. Feito isso é selecionao uma das 3 escolas de maneira aleatória
#
# - Para o cenário múltiplo de `Pop350`, fazemos uma redução proporcional no número de escolas com a função `random.choices`

# %% [markdown]
# ### Redução no número de escolas
#
# Para acompanhar a redução na população, fazemos uma redução proporcional no número de escolas

# %%
plt.figure(figsize=(16,6))
plt.imshow(escolas_municipais, cmap='Blues', interpolation='none')
plt.colorbar()
plt.grid(False)
plt.title(f'Distribuição das {escolas_municipais.sum()} escolas', fontsize=16)
plt.show()

# %%
tx_reducao = 100
esc_escolha, dist_escolas = rede_escolar.distribui_escolas(tx_reducao, escolas_municipais)

# %%
plt.figure(figsize=(16,6))
plt.imshow(dist_escolas, cmap='Blues', interpolation='none')
plt.colorbar()
plt.grid(False)
plt.title(f'Distribuição das {dist_escolas.sum()} escolas, após redução', fontsize=16)
plt.show()

# %% [markdown]
# ## Distribuição das idades

# %% [markdown]
# ## Pirâmide etária do rio de Janeiro
#
# - Como as pirâmides etárias do Rio de Janeiro e do Brasil são razoavelmente diferentes, vamos trabalhar com os dados do Rio.
#
# - Inicialmente, consideramos a pirâmide populacional da cidade do Rio de Janeiro disponível na [Tabela do IPP/Data Rio](https://www.data.rio/datasets/popula%C3%A7%C3%A3o-residente-por-grupos-de-idade-e-sexo-segundo-as-%C3%A1reas-de-planejamento-ap-e-regi%C3%B5es-administrativas-ra-no-munic%C3%ADpio-do-rio-de-janeiro-2010)

# %%
num_pop = pop_por_blocos.sum()

piramide_etaria = pd.read_csv('../../../../dados/RJ/cidade_rj/dados_estatisticos/piramide_etaria_MRJ.csv')
idades_grupos = np.array([int(p[0:2]) for p in piramide_etaria.columns[1:]])
idades_grupos[-1] = 100
idades_fracoes_grupos = piramide_etaria.iloc[0][1:].values/piramide_etaria.iloc[0][0]

idade_max = 100
pop_idades = episiming.cenarios.gera_idades(67973, 8, res_individuos, idades_grupos, idades_fracoes_grupos, idade_max = 100)
# Out:
# /home/gil/repos/covid19/episiming/cenarios.py:232: RuntimeWarning: divide by zero encountered in double_scalars
#   * [idades_fracoes_grupos[-1]/(idade_max-idades_grupos[-1])]

# %%
dist_idades_na_escola = rede_escolar.distribuicao_idade(num_pop, censo_residencial, res_individuos, pop_idades, piramide_etaria, idades_grupos, idades_fracoes_grupos, idade_max)

# %% [markdown]
# ### Escolhendo os alunos

# %%
alunos = rede_escolar.escolhe_alunos_idade(pop_idades, dist_idades_na_escola)

# %% [markdown]
# ## Alocando população escolar nas escolas
#
# ### Gerando a localização das escolas

# %%
escolas = rede_escolar.aloca_alunos(alunos, esc_escolha, pos_individuos)

# %% [markdown]
# ## Criando a rede

# %%
for aluno in escolas:
    if len(aluno) > 1:
        print([(i,j) for i in aluno for j in aluno if i < j])
# Out:
# [(14141, 17858), (14141, 39752), (14141, 26553), (14141, 43442), (14141, 22201), (14141, 31218), (14141, 14240), (14141, 26537), (14141, 17817), (14141, 22134), (14141, 22248), (14141, 14301), (14141, 17724), (14141, 47376), (14141, 39942), (14141, 31217), (14141, 39904), (14141, 14311), (14141, 17965), (14141, 39681), (14141, 47227), (14141, 14261), (14141, 43278), (14141, 14296), (14141, 26567), (14141, 47365), (14141, 26507), (14141, 14288), (14141, 31136), (14141, 47294), (14141, 31269), (14141, 31079), (14141, 47230), (14141, 17725), (14141, 47300), (14141, 22230), (14141, 43449), (14141, 17884), (14141, 17959), (14141, 18010), (14141, 17712), (14141, 39940), (14141, 31265), (14141, 39817), (14141, 31167), (14141, 22194), (14141, 14249), (14141, 22222), (14141, 26471), (14141, 22155), (14141, 26530), (14141, 22329), (14141, 39825), (14141, 17789), (14141, 39826), (14141, 22226), (14141, 22322), (14141, 43274), (14141, 47310), (14141, 47326), (14141, 43403), (14141, 39969), (14141, 17871), (14141, 22306), (14141, 17865), (14141, 17850), (14141, 31204), (14141, 22235), (14141, 31214), (14141, 47317), (14141, 43217), (14141, 22068), (14141, 22245), (14141, 22219), (14141, 26462), (14141, 43422), (14141, 31133), (14141, 14284), (14141, 39939), (14141, 17879), (14141, 39870), (14141, 22234), (14141, 35988), (14141, 39960), (14141, 18019), (14141, 22122), (14141, 39967), (14141, 22131), (14141, 22147), (14141, 47297), (14141, 39867), (14141, 22210), (14141, 39749), (14141, 47381), (14141, 43342), (14141, 26472), (14141, 39768), (14141, 39663), (14141, 43275), (14141, 39910), (14141, 47380), (14141, 22297), (14141, 39964), (14141, 14319), (14141, 26372), (14141, 39883), (14141, 31170), (14141, 26381), (14141, 39861), (14141, 39821), (14141, 17992), (14141, 26536), (14141, 14143), (14141, 31207), (14141, 22300), (14141, 17882), (14141, 43407), (14141, 35973), (14141, 22311), (14141, 43417), (14141, 35984), (14141, 39918), (14141, 47303), (14141, 39824), (14141, 43207), (14141, 39814), (14141, 47379), (14141, 43288), (14141, 47377), (14141, 26473), (14141, 14367), (14141, 35977), (14141, 26549), (14141, 43344), (14141, 18004), (14141, 39879), (14141, 47358), (14141, 43441), (14141, 17729), (14141, 17948), (14141, 43198), (14141, 17987), (14141, 14243), (14141, 17715), (14141, 43349), (14141, 43338), (14141, 17968), (14141, 43283), (14141, 17846), (14141, 35985), (14141, 17936), (14141, 43279), (14141, 17983), (14141, 43258), (14141, 17721), (14141, 39884), (11316, 14141), (11316, 17858), (11316, 39752), (11316, 26553), (11316, 43442), (11316, 22201), (11316, 31218), (11316, 13942), (11316, 14240), (11316, 26537), (11316, 17817), (11316, 22134), (11316, 22248), (11316, 14301), (11316, 17724), (11316, 47376), (11316, 39942), (11316, 31217), (11316, 39904), (11316, 14311), (11316, 17965), (11316, 39681), (11316, 47227), (11316, 14261), (11316, 43278), (11316, 14296), (11316, 26567), (11316, 14121), (11316, 47365), (11316, 13962), (11316, 14083), (11316, 26507), (11316, 11350), (11316, 14288), (11316, 31136), (11316, 47294), (11316, 31269), (11316, 31079), (11316, 47230), (11316, 17725), (11316, 47300), (11316, 11348), (11316, 13967), (11316, 22230), (11316, 43449), (11316, 17884), (11316, 11340), (11316, 17959), (11316, 18010), (11316, 14074), (11316, 17712), (11316, 39940), (11316, 31265), (11316, 39817), (11316, 31167), (11316, 13919), (11316, 22194), (11316, 14249), (11316, 22222), (11316, 26471), (11316, 22155), (11316, 26530), (11316, 22329), (11316, 11336), (11316, 13916), (11316, 39825), (11316, 17789), (11316, 11337), (11316, 39826), (11316, 22226), (11316, 22322), (11316, 43274), (11316, 47310), (11316, 47326), (11316, 43403), (11316, 39969), (11316, 17871), (11316, 22306), (11316, 13945), (11316, 17865), (11316, 17850), (11316, 31204), (11316, 22235), (11316, 31214), (11316, 47317), (11316, 43217), (11316, 22068), (11316, 22245), (11316, 13934), (11316, 14100), (11316, 13937), (11316, 22219), (11316, 26462), (11316, 43422), ...
# [(63162, 67002), (63162, 66367), (63162, 67032), (63162, 63163), (63162, 64954), (63162, 66363), (63162, 66925), (63162, 66941), (63162, 66978), (63162, 64984), (63162, 67005), (63162, 64959), (63162, 66403), (63162, 63966), (63162, 63964), (63162, 67001), (63162, 64970), (63162, 66401), (63162, 64981), (63162, 67006), (63162, 66942), (63162, 66918), (63162, 64982), (63162, 66360), (67002, 67032), (67002, 67005), (67002, 67006), (66367, 67002), (66367, 67032), (66367, 66925), (66367, 66941), (66367, 66978), (66367, 67005), (66367, 66403), (66367, 67001), (66367, 66401), (66367, 67006), (66367, 66942), (66367, 66918), (63163, 67002), (63163, 66367), (63163, 67032), (63163, 64954), (63163, 66363), (63163, 66925), (63163, 66941), (63163, 66978), (63163, 64984), (63163, 67005), (63163, 64959), (63163, 66403), (63163, 63966), (63163, 63964), (63163, 67001), (63163, 64970), (63163, 66401), (63163, 64981), (63163, 67006), (63163, 66942), (63163, 66918), (63163, 64982), (63163, 66360), (64954, 67002), (64954, 66367), (64954, 67032), (64954, 66363), (64954, 66925), (64954, 66941), (64954, 66978), (64954, 64984), (64954, 67005), (64954, 64959), (64954, 66403), (64954, 67001), (64954, 64970), (64954, 66401), (64954, 64981), (64954, 67006), (64954, 66942), (64954, 66918), (64954, 64982), (64954, 66360), (66363, 67002), (66363, 66367), (66363, 67032), (66363, 66925), (66363, 66941), (66363, 66978), (66363, 67005), (66363, 66403), (66363, 67001), (66363, 66401), (66363, 67006), (66363, 66942), (66363, 66918), (66925, 67002), (66925, 67032), (66925, 66941), (66925, 66978), (66925, 67005), (66925, 67001), (66925, 67006), (66925, 66942), (66941, 67002), (66941, 67032), (66941, 66978), (66941, 67005), (66941, 67001), (66941, 67006), (66941, 66942), (63149, 63162), (63149, 67002), (63149, 66367), (63149, 67032), (63149, 63163), (63149, 64954), (63149, 66363), (63149, 66925), (63149, 66941), (63149, 66978), (63149, 64984), (63149, 67005), (63149, 64959), (63149, 66403), (63149, 63161), (63149, 63966), (63149, 63964), (63149, 67001), (63149, 64970), (63149, 66401), (63149, 64981), (63149, 67006), (63149, 66942), (63149, 66918), (63149, 63158), (63149, 64982), (63149, 66360), (66978, 67002), (66978, 67032), (66978, 67005), (66978, 67001), (66978, 67006), (64984, 67002), (64984, 66367), (64984, 67032), (64984, 66363), (64984, 66925), (64984, 66941), (64984, 66978), (64984, 67005), (64984, 66403), (64984, 67001), (64984, 66401), (64984, 67006), (64984, 66942), (64984, 66918), (64984, 66360), (67005, 67032), (67005, 67006), (64959, 67002), (64959, 66367), (64959, 67032), (64959, 66363), (64959, 66925), (64959, 66941), (64959, 66978), (64959, 64984), (64959, 67005), (64959, 66403), (64959, 67001), (64959, 64970), (64959, 66401), (64959, 64981), (64959, 67006), (64959, 66942), (64959, 66918), (64959, 64982), (64959, 66360), (66403, 67002), (66403, 67032), (66403, 66925), (66403, 66941), (66403, 66978), (66403, 67005), (66403, 67001), (66403, 67006), (66403, 66942), (66403, 66918), (63161, 63162), (63161, 67002), (63161, 66367), (63161, 67032), (63161, 63163), (63161, 64954), (63161, 66363), (63161, 66925), (63161, 66941), (63161, 66978), (63161, 64984), (63161, 67005), (63161, 64959), (63161, 66403), (63161, 63966), (63161, 63964), (63161, 67001), (63161, 64970), (63161, 66401), (63161, 64981), (63161, 67006), (63161, 66942), (63161, 66918), (63161, 64982), (63161, 66360), (63966, 67002), (63966, 66367), (63966, 67032), (63966, 64954), (63966, 66363), (63966, 66925), (63966, 66941), (63966, 66978), (63966, 64984), (63966, 67005), (63966, 64959), (63966, 66403), (63966, 67001), (63966, 64970), (63966, 66401), (63966, 64981), (63966, 67006), (63966, 66942), (63966, 66918), (63966, 64982), (63966, 66360), (61822, 63162), (61822, 67002), (61822, 66367), (61822, 67032), (61822, 63163), (61822, 64954), (61822, 66363), (61822, 66925), (61822, 66941), (61822, 63149), (61822, 66978), (61822, 64984), (61822, 67005), (61822, 64959), (61822, 66403), (61822, 63161), ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
G_esc = rede_escolar.gera_rede_escolar(num_pop, attrib_pos_individuos, escolas)

# %%
# plt.figure(figsize=(12,6))
# nx.draw(G_esc, pos=attrib_pos_individuos, node_size=1, alpha=0.5)
# plt.show()

# %% [markdown]
# ---

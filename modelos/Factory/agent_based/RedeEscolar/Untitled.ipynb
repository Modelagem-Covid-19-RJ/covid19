# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('MATRICULAS_FUNCIONARIOS_DOCENTES_RJ - ESCOLAS.csv')

# %%
df
# Out:
#       PK_COD_ENTIDADE                                        NO_ENTIDADE  \
# 0            33062234                               COL PONTO DE PARTIDA
# 1            33062250                                        CE ALDEBARA
# 2            33062277                                            CE CUBA
# 3            33062293                                 CE CHARLES DICKENS
# 4            33062340     CAIC JOAQUIM JOSE DA SILVA XAVIER O TIRADENTES
# ...               ...                                                ...
# 3903         33543216                       CENTRO EDUCACIONAL MENE LTDA
# 3904         33547211              SANTA MONICA CENTRO EDUCACIONAL - CEP
# 3905         33552231  COLEGIO E CURSO CARPE DIEM ASSESSORIA E EMPREE...
# 3906         33556210               CRECHE ESCOLA COMUNITARIA MAE SOCIAL
# 3907         33558230                        CE DEPUTADO PEDRO FERNANDES
#
#       MAT_CRECHE  MAT_PRE  MAT_FUND  MAT_MEDIO
# ...

# %%
dist_tam = df[['MAT_CRECHE', 'MAT_PRE', 'MAT_FUND', 'MAT_MEDIO']].sum(axis = 1).values

# %%
rng = np.arange(len(df))

# %%
rng[dist_tam > 2000]
# Out:
# array([  81,  154,  160,  279, 1261, 1293, 1517, 1518, 1682, 1711, 1723,
#        1786, 2268, 2501])

# %%
984+689+453
# Out:
# 2126

# %%
df.iloc[2501]
# Out:
# PK_COD_ENTIDADE                                             33136505
# NO_ENTIDADE        CE PROFESSORA JEANNETTE DE SOUZA COELHO MANNARINO
# MAT_CRECHE                                                         0
# MAT_PRE                                                            0
# MAT_FUND                                                           0
# MAT_MEDIO                                                       2353
# Name: 2501, dtype: object

# %%
np.sum(dist_tam)
# Out:
# 1215612

# %%
np.min(dist_tam[dist_tam > 25])
# Out:
# 26

# %%
plt.figure(figsize = (20,12))
plt.plot(dist_tam)

# %%
plt.figure(figsize=(20,12))
rslt = plt.boxplot(dist_tam)

# %%
plt.figure(figsize=(20,12))
plt.hist(dist_tam,bins=50)
plt.hist(dist_tam,bins=50)
plt.show()

# %%
np.mean(dist_tam)
# Out:
# 311.057318321392

# %%
np.median(dist_tam)
# Out:
# 221.0

# %%
np.min(dist_tam[dist_tam > 0])
# Out:
# 1

# %%
np.max(dist_tam[dist_tam > 0])
# Out:
# 2853

# %%
from scipy.stats import lognorm

# %%
s = 3.39

mean, var, skew, kurt = lognorm.stats(s, moments='mvsk')

# %%
rv = lognorm(s)

# %%
x = np.linspace(lognorm.ppf(0.01, s),

                lognorm.ppf(0.99, s), 3908)

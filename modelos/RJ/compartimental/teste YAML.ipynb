# %%
import modcovid as mc
from modcovid import settings, scripts

# %%
import pandas as pd

# %%
df = pd.read_csv('Dados_indiv_MRJ_covid19.csv', encoding = 'iso-8859-1', delimiter = ';')

# %%
df
# Out:
#      classificação_final  dt_notific dt_inicio_sintomas bairro_resid__estadia  \
# 0             CONFIRMADO  10/03/2020         08/03/2020     FORA DO MUNICÍPIO
# 1             CONFIRMADO  20/03/2020         14/03/2020            COPACABANA
# 2             CONFIRMADO  15/03/2020         12/03/2020            COPACABANA
# 3             CONFIRMADO  24/03/2020                NaN           SAO CONRADO
# 4             CONFIRMADO  20/03/2020                NaN       JARDIM BOTANICO
# ...                  ...         ...                ...                   ...
# 6745          CONFIRMADO  02/05/2020                NaN          CAMPO GRANDE
# 6746          CONFIRMADO  02/05/2020                NaN            INDEFINIDO
# 6747          CONFIRMADO  02/05/2020                NaN          CAMPO GRANDE
# 6748          CONFIRMADO  02/05/2020                NaN            INDEFINIDO
# 6749          CONFIRMADO  02/05/2020                NaN                 BANGU
#
# ...

# %%
df, dt_att = mc.scripts.set_df('prefeitura_rj')

# %%
df
# Out:
#      Classificacao        Data DataSintomas             Bairro   AP Sexo  \
# 0       CONFIRMADO  10/03/2020   08/03/2020  FORA DO MUNICÍPIO  N/D    M
# 1       CONFIRMADO  20/03/2020   14/03/2020         COPACABANA  2.1    F
# 2       CONFIRMADO  15/03/2020   12/03/2020         COPACABANA  2.1    F
# 3       CONFIRMADO  24/03/2020          NaN        SAO CONRADO  2.1    M
# 4       CONFIRMADO  20/03/2020          NaN    JARDIM BOTANICO  2.1    M
# ...            ...         ...          ...                ...  ...  ...
# 6745    CONFIRMADO  02/05/2020          NaN       CAMPO GRANDE  5.2    F
# 6746    CONFIRMADO  02/05/2020          NaN         INDEFINIDO  N/D    M
# 6747    CONFIRMADO  02/05/2020          NaN       CAMPO GRANDE  5.2    F
# 6748    CONFIRMADO  02/05/2020          NaN         INDEFINIDO  N/D    F
# 6749    CONFIRMADO  02/05/2020          NaN              BANGU  5.1    F
#
#      FaixaEtaria    Evolucao
# 0     De 30 a 39  recuperado
# 1            N/D  recuperado
# ...

# %%
dt_att
# Out:
# '03/05/2020'
